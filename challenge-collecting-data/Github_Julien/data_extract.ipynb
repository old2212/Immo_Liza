# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import time

url = "https://www.immoweb.be/fr/annonce/immeuble-mixte/a-vendre/grimbergen/1850/10138527?searchId=6334a2298fb71"

driver = webdriver.Firefox()
driver.get(url)

#print(driver.title)
#assert "Immoweb" in driver.title

time.sleep(3)
cookie_button = driver.find_element(By.XPATH, "//*[@id='uc-btn-accept-banner']")
time.sleep(1)
cookie_button.click()
time.sleep(1)


page_urls = []
table_rows = driver.find_elements(By.XPATH, "//tr[@class = 'classified-table__row']")
for table_row in table_rows:
    try:
        tr_header = table_row.find_element(By.XPATH, ".//th")
        tr_data = table_row.find_element(By.XPATH, ".//td")
    except NoSuchElementException:
        pass

    #print(table_row.text)
    print(tr_header.text)
    print(tr_data.text)
    #print(type(tr_data)) #Elément
    #print(type(tr_data.text))

driver.close()
# Out:
# Année de construction
# 1965
# État du bâtiment
# À rénover
# Largeur de la façade à rue
# 7 m
# Nombre de façades
# 3
# Parkings intérieurs
# 3
# Parkings extérieurs
# 6
# Surface habitable
# 270 m²
# mètres carrés
# Surface du salon
# 23 m²
# mètres carrés
# Type de cuisine
# Semi-équipée
# Surface de la cuisine
# 15 m²
# mètres carrés
# Chambres
# 4
# Surface de la chambre 1
# 13 m²
# mètres carrés
# Surface de la chambre 2
# 13 m²
# mètres carrés
# Surface de la chambre 3
# 12 m²
# mètres carrés
# Salles de bains
# 2
# Toilettes
# 4
# Surface de la cave
# 39 m²
# mètres carrés
# Meublé
# Non
# Surface du terrain
# 1205 m²
# mètres carrés
# Largeur du terrain à rue
# 10 m
# mètres
# Eau, gaz & électricité
# Oui
# Surface du jardin
# 400 m²
# mètres carrés
# Orientation du jardin
# Nord-ouest
# Consommation d'énergie primaire
# 459 kWh/m²
# kilowattheure par mètres carrés
# Classe énergétique
# E
#
# E
# Numéro du rapport PEB
# 20220909-0002671347-RES-1
# Emission CO₂
# Non communiqué
# Consommation théorique totale d'énergie primaire
# Non communiqué
# Attestation as-built
# Non
# Type de chauffage
# Mazout
# Droit d'achat prioritaire possible
# Oui
# Type de zone inondable
# Zone inondable potentielle
# Affectation urbanistique la plus récente sur la base des dénominations utilisées dans le registre des plans
# Zone agricole
# Revenu cadastral
# 2.466 €
# 2466 €
# Immeuble de rapport
# Oui
# Immeuble de rapport
# Oui
# Adresse
# James Ensorlaan 39
# 1800 - Vilvoorde
# Site internet
# http://www.ringconsult.be
# Référence externe
# 1980229 - 1579
