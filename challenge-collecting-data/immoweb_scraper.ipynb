# %% [markdown]
# ## Get houses/apps urls from ONE Immoweb page.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

url = "https://www.immoweb.be/en/search/house-and-apartment/for-sale?countries=BE&page=1&orderBy=relevance"

driver = webdriver.Firefox()
driver.get(url)

#print(driver.title)
#assert "Immoweb" in driver.title

time.sleep(3)
cookie_button = driver.find_element(By.XPATH, "//*[@id='uc-btn-accept-banner']")
time.sleep(1)
cookie_button.click()
time.sleep(1)


page_urls = []
house_urls = driver.find_elements(By.XPATH, "//h2/a[@href]")
for house_url in house_urls:
    if "From" not in house_url.get_attribute('aria-label'):
        page_urls.append(house_url.get_attribute('href'))
        print (house_url.get_attribute('aria-label'))
        print(type(house_url.get_attribute('aria-label')))

print(page_urls)

driver.close()
# Out:
# House for sale, Ronse (129000€)
# <class 'str'>
# Apartment for sale, Woluwe-St-Lambert (249000€)
# <class 'str'>
# New real estate project - Apartments for sale, Gent (260000€)
# <class 'str'>
# House for sale, Remicourt (300000€)
# <class 'str'>
# Apartment for sale, Woluwe-Saint-Lambert (340000€)
# <class 'str'>
# Apartment for sale, Deinze (375000€)
# <class 'str'>
# Duplex for sale, Wichelen (225000€)
# <class 'str'>
# Apartment for sale, Leuven (310000€)
# <class 'str'>
# House for sale, Ronse (359000€)
# <class 'str'>
# Apartment for sale, Wezembeek-Oppem (390000€)
# <class 'str'>
# New real estate project - Houses for sale, Wetteren (395000€)
# <class 'str'>
# Apartment for sale, Woluwe-Saint-Lambert (595000€)
# <class 'str'>
# Mixed-use building for sale, Grimbergen (595000€)
# <class 'str'>
# Apartment block for sale, Ixelles (1000000€)
# <class 'str'>
# Studio for sale, Huy (89000€)
# <class 'str'>
# Studio for sale, Schaerbeek (195000€)
# <class 'str'>
# Apartment for sale, Bruxelles (275000€)
# <class 'str'>
# New real estate project - Houses for sale, Forest (340980€)
# <class 'str'>
# House for sale, Woluwe-Saint-Pierre (990000€)
# <class 'str'>
# ['https://www.immoweb.be/en/classified/house/for-sale/ronse/9600/10140837?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/apartment/for-sale/woluwe-st-lambert/1200/10052020?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/gent/9000/10140797?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/house/for-sale/remicourt/4350/10140833?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/apartment/for-sale/woluwe-saint-lambert/1200/10140583?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/apartment/for-sale/deinze/9800/10130388?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/duplex/for-sale/wichelen/9260/10138456?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/apartment/for-sale/leuven/3010/10138534?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/house/for-sale/ronse/9600/10138497?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/apartment/for-sale/wezembeek-oppem/1970/10140213?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/new-real-estate-project-houses/for-sale/wetteren/9230/10138446?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/apartment/for-sale/woluwe-saint-lambert/1200/10138633?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/mixed-use-building/for-sale/grimbergen/1850/10138527?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/apartment-block/for-sale/ixelles/1050/10138311?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/flat-studio/for-sale/huy/4500/10137075?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/flat-studio/for-sale/schaerbeek/1030/10137594?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/apartment/for-sale/bruxelles/1000/10137385?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/new-real-estate-project-houses/for-sale/forest/2430/10138007?searchId=6335755070ce8', 'https://www.immoweb.be/en/classified/house/for-sale/woluwe-saint-pierre/1150/10135994?searchId=6335755070ce8']

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import time
import re

url = "https://www.immoweb.be/fr/annonce/immeuble-mixte/a-vendre/grimbergen/1850/10138527?searchId=6334a2298fb71"

driver = webdriver.Firefox()
driver.get(url)

#print(driver.title)
#assert "Immoweb" in driver.title

time.sleep(3)
cookie_button = driver.find_element(By.XPATH, "//*[@id='uc-btn-accept-banner']")
time.sleep(1)
cookie_button.click()
time.sleep(1)


page_contain = {}
table_rows = driver.find_elements(By.XPATH, "//tr[@class = 'classified-table__row']")
for table_row in table_rows:
    try:
        tr_header = table_row.find_element(By.XPATH, ".//th").text
        tr_data = ''.join(table_row.find_element(By.XPATH, ".//td").text)
        
    except NoSuchElementException:
        pass
    page_contain[tr_header] = tr_data

    #print(table_row.text)
print(page_contain)
    #print(type(tr_data)) #Elément
    #print(type(tr_data.text))

driver.close()
# Out:
# {'Année de construction': '1965', 'État du bâtiment': 'À rénover', 'Largeur de la façade à rue': '7 m', 'Nombre de façades': '3', 'Parkings intérieurs': '3', 'Parkings extérieurs': '6', 'Surface habitable': '270 m²\nmètres carrés', 'Surface du salon': '23 m²\nmètres carrés', 'Type de cuisine': 'Semi-équipée', 'Surface de la cuisine': '15 m²\nmètres carrés', 'Chambres': '4', 'Surface de la chambre 1': '13 m²\nmètres carrés', 'Surface de la chambre 2': '13 m²\nmètres carrés', 'Surface de la chambre 3': '12 m²\nmètres carrés', 'Salles de bains': '2', 'Toilettes': '4', 'Surface de la cave': '39 m²\nmètres carrés', 'Meublé': 'Non', 'Surface du terrain': '1205 m²\nmètres carrés', 'Largeur du terrain à rue': '10 m\nmètres', 'Eau, gaz & électricité': 'Oui', 'Surface du jardin': '400 m²\nmètres carrés', 'Orientation du jardin': 'Nord-ouest', "Consommation d'énergie primaire": '459 kWh/m²\nkilowattheure par mètres carrés', 'Classe énergétique': 'E', '': 'E', 'Numéro du rapport PEB': '20220909-0002671347-RES-1', 'Emission CO₂': 'Non communiqué', "Consommation théorique totale d'énergie primaire": 'Non communiqué', 'Attestation as-built': 'Non', 'Type de chauffage': 'Mazout', "Droit d'achat prioritaire possible": 'Oui', 'Type de zone inondable': 'Zone inondable potentielle', 'Affectation urbanistique la plus récente sur la base des dénominations utilisées dans le registre des plans': 'Zone agricole', 'Revenu cadastral': '2.466 €\n2466 €', 'Immeuble de rapport': 'Oui', 'Adresse': 'James Ensorlaan 39\n1800 - Vilvoorde', 'Site internet': 'http://www.ringconsult.be', 'Référence externe': '1980229 - 1579'}

# %%
columns_names: list[str] = open('colums_names.txt', 'r').read().lower().split('\n')

print(columns_names)
# Out:
# ['locality', 'type of property (house/apartment)', 'subtype of property (bungalow, chalet, mansion, ...)', 'price', 'type of sale (exclusion of life sales)', 'number of rooms', 'area', 'fully equipped kitchen (yes/no)', 'furnished (yes/no)', 'open fire (yes/no)', 'terrace (yes/no)', 'if yes: area', 'garden (yes/no)', 'if yes: area', 'surface of the land', 'surface area of the plot of land', 'number of facades', 'swimming pool (yes/no)', 'state of the building (new, to be renovated, ...)', '']
